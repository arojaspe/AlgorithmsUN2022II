# %%
print("Certificados Lab 3 \n Andres Rojas Pedroza")
# Out:
# Certificados Lab 3
#  Andres Rojas Pedroza

# %% [markdown]
# [LinkedIn Andres Rojas Pedroza](https://https://www.linkedin.com/in/andres-rojas-pedroza-267495222/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
